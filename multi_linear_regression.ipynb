# %% [markdown]
# <a href="https://colab.research.google.com/github/rai-shi/Machine-Learning-Gelecegi-Yazanlar/blob/main/multi_linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/Advertising.csv")
df
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df = df.iloc[:,1:]
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
X = df.drop("sales", axis=1)
Y = df[["sales"]] # make it pandas dataframe, [] numpy array [[]] dataframe

# %%
X.head()
# Out:
#       TV  radio  newspaper
# 0  230.1   37.8       69.2
# 1   44.5   39.3       45.1
# 2   17.2   45.9       69.3
# 3  151.5   41.3       58.5
# 4  180.8   10.8       58.4

# %%
Y.head()
# Out:
#    sales
# 0   22.1
# 1   10.4
# 2    9.3
# 3   18.5
# 4   12.9

# %%
# statsmodels ile model kurmak
# daha fazla bilgi, doğrusal modellerin yapısına uygun bazı sonuçlar

# %%
import statsmodels.api as sm

# %%
model = sm.OLS(Y,X).fit() # ordinary least square

# %%
model.summary() # model output
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared (uncentered):                   0.982
# Model:                            OLS   Adj. R-squared (uncentered):              0.982
# Method:                 Least Squares   F-statistic:                              3566.
# Date:                Wed, 05 Feb 2025   Prob (F-statistic):                   2.43e-171
# Time:                        16:38:41   Log-Likelihood:                         -423.54
# No. Observations:                 200   AIC:                                      853.1
# Df Residuals:                     197   BIC:                                      863.0
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# r2 bağımsız değişkenlerin bağımlı değişkeni açıklama yüzdesi, üç değişken ile %98 oranında sales değişkeni açıklanabilmektedir
#
# düzeltilmiş r2, r2 formülasyonu itibari ile veri setine ne kadar değişken eklenirse eklensin artmaya meyilldir. iligli ilgisiz birçok değişkeni modele dahil eder.
#
# r2 artması her zaman açıklanabilirliğe katkı sağlamaz o yüzden düzeltilmiş r2 daha tutarlıdır
#
# f istatistiği modelin anlamlılığına dair istatistiksel test sonucu (0.05 den küçük olmalı ki anlamlı olsun)
#
# alltaki tablo veri setindeki değişkene ait bilgileri içeriyor.
# coef beta katsayıları, std err katsayıların standart hatası,
# t istatistiği ve p value ile değişkenlerin anlamlılığı, hepsi 0.05 den küçük olduğu için anlamlıdır. h0 anlamlı değildir der.
#
# bir bağımsız değişkenin katsayısı x birim ise diğerlerinin sabit olduğu durumda x katsayılı değişkenin bir birimlik değişimi bağımlı değişkene x birim etki eder. bağımsız değişkenlerin bağımlı değişkene nasıl etki edeceğinin birimidirler.

# %%
# skitlearn ile model kurmak
# sadece katsayılar

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
model = lm.fit(X, Y)

# %%
print(model.coef_)
# Out:
# [[ 0.04576465  0.18853002 -0.00103749]]

# %%
print(model.intercept_)
# Out:
# [2.93888937]

# %%
# katsayılar parametre tahmin yöntemleri farklı olmsaından farklılaştı

# %% [markdown]
# **model**

# %%
print ("sales = %.2f + TV*%.2f + radio*%.2f + newspaper*%.5f" % (model.intercept_, model.coef_[0][0], model.coef_[0][1], model.coef_[0][2]) )
# Out:
# sales = 2.94 + TV*0.05 + radio*0.19 + newspaper*-0.00104
# <ipython-input-29-31ce5adc20e4>:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print ("sales = %.2f + TV*%.2f + radio*%.2f + newspaper*%.5f" % (model.intercept_, model.coef_[0][0], model.coef_[0][1], model.coef_[0][2]) )

# %%
new_data = [
    [30, 10, 40],
    [5, 25, 80],
    [45, 100, 12],
]

new_data = pd.DataFrame(new_data, columns=["TV", "radio", "newspaper"])
new_data
# Out:
#    TV  radio  newspaper
# 0  30     10         40
# 1   5     25         80
# 2  45    100         12

# %%
model.predict(new_data)
# Out:
# array([[ 6.15562918],
#        [ 7.79796358],
#        [23.83885019]])

# %%
for i in range(len(new_data)):
  sales = model.intercept_ + new_data.iloc[i,0]*model.coef_[0][0] + new_data.iloc[i,1]*model.coef_[0][1] + new_data.iloc[i,2]*model.coef_[0][2]
  print(sales)
# Out:
# [6.15562918]
# [7.79796358]
# [23.83885019]

# %%
# model performansı

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
mse = mean_squared_error(Y, model.predict(X))
mse
# Out:
# 2.784126314510936

# %%
rmse = np.sqrt(mse)
rmse
# Out:
# 1.6685701407225697

# %%
# model tuning, model doğrulama

# %%
# çoklu doğrusal regresyon modelinde bir hiper parametre yoktur bu durumda burada model doğrulama işlemleri gerçekleşecek
# sınama seti ve k katlı çaprazlama ile yapacağız

# %%
X.head()
# Out:
#       TV  radio  newspaper
# 0  230.1   37.8       69.2
# 1   44.5   39.3       45.1
# 2   17.2   45.9       69.3
# 3  151.5   41.3       58.5
# 4  180.8   10.8       58.4

# %%
Y.head()
# Out:
#    sales
# 0   22.1
# 1   10.4
# 2    9.3
# 3   18.5
# 4   12.9

# %%
# sınama seti, holdout
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state=99)

# %%
x_train.head()
# Out:
#         TV  radio  newspaper
# 16    67.8   36.6      114.0
# 51   100.4    9.6        3.6
# 97   184.9   21.0       22.0
# 164  117.2   14.7        5.4
# 71   109.8   14.3       31.7

# %%
X.shape
# Out:
# (200, 3)

# %%
x_train.shape
# Out:
# (160, 3)

# %%
x_test.shape
# Out:
# (40, 3)

# %%
model2 = LinearRegression().fit(x_train, y_train)

# %%
# train error
np.sqrt(mean_squared_error(y_train, model2.predict(x_train)))
# Out:
# 1.7236824822650754

# %%
# test error
np.sqrt(mean_squared_error(y_test, model2.predict(x_test)))
# Out:
# 1.4312783138301641

# %%
# k-katlı cross validation
from sklearn.model_selection import cross_val_score
errors = cross_val_score(model2, x_train, y_train, cv=10, scoring="neg_mean_squared_error")
errors
# Out:
# array([-2.1019073 , -2.48953197, -3.09704214, -2.34694216, -3.68175761,
#        -1.8691401 , -3.18173007, -4.1927349 , -2.17128376, -8.03821974])

# %%
# train seti içinden 10 farklı hata elde edildi en son ortalama alındığında train setinin ortalama hatası elde ediliyor

# %%
np.mean(-errors) # cv mse
# Out:
# 3.3170289742341246

# %%
np.sqrt(np.mean(-errors)) # cv rmse
# Out:
# 1.8212712522395242

# %%
# veri seti yeteri kadar büyükse train test yapıp trainde cv uygulayıp en son bir de testseti ile test yapılabilir
# eğer küçük bir veri seti ise o halde X Y üzerinden çalışılır
